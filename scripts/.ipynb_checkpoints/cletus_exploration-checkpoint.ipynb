# %%
#importing dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from wordcloud import WordCloud, STOPWORDS
from nltk.corpus import stopwords

# %%
#read the tweets data
tweets_df = pd.read_csv("Tweets_source_data.csv")
# 
# tweets_df.head()

# %%
#displays tweets share by airlines
tweets_df.airline.value_counts().plot(kind='pie', autopct='%1.0f%%', radius=1.45, label='',shadow=True)
plt.savefig('../images/airlinestweets.png')

# %%
#display count of the different sentiments - negative, neutral, positive
tweets_df.airline_sentiment.value_counts().plot(kind='pie', autopct='%1.0f%%', radius=1.48, label='',shadow=True)
plt.savefig('../images/tweetsenti.png')

# %%
#represent sentiments by airlines on a bar chart
tweets_df.groupby(['airline', 'airline_sentiment']).airline_sentiment.count().unstack().plot(kind='bar', figsize=(12,7), legend=True, title='Tweets by Airlines')
plt.savefig('../images/tweets_by_sent.png')
#plt.legend(loc='best')
# sentiment_airline.plot(kind='bar', loc='best')

# sns.catplot(x="airline", y="countval", hue="airline_sentiment", data=sentiment_airline,
#             height=6, kind="bar", palette="muted")

# %% [markdown]
# # Text Processing
# - Looking through the different tweets

# %%
# df = tweets_df['text'][0].split()
# df = lamda x: for x in df

# %%
#processing each individual tweet, by removing multiple spaces, single character
tweets = tweets_df['text']
tweets

processed_tweets = []

for line in range(0, len(tweets)):
    proc_line = tweets[line].split()[1:]
    # Remove all the special characters
    proc_line = re.sub(r'\W', ' ', str(tweets[line]))

    # remove all single characters
    proc_line= re.sub(r'\s+[a-zA-Z]\s+', ' ', proc_line)

    # Remove single characters from the start
    proc_line = re.sub(r'\^[a-zA-Z]\s+', ' ', proc_line) 

    # Substituting multiple spaces with single space
    proc_line = re.sub(r'\s+', ' ', proc_line, flags=re.I)

    # Removing prefixed 'b'
    proc_line = re.sub(r'^b\s+', '', proc_line)

    # Converting to Lowercase
    proc_line = proc_line.lower()
    
    # remove the name of the airline
    proc_line = ' '.join(proc_line.split()[1:])
    
    # add to the created list
    processed_tweets.append(proc_line)
    
#     processed_tweets = ' '.join(processed_tweets.split()[1:])
    
#processed_tweets = pd.DataFrame(processed_tweets)
# processed_tweets = ' '.join(processed_tweets.split()[1:])
tweets_df['tweets'] = processed_tweets
tweets_df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone  \
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)
#
#                                               tweets
# 0                                 what dhepburn said
# 1  plus you ve added commercials to the experienc...
# 2     didn today must mean need to take another trip
# 3  it really aggressive to blast obnoxious entert...
# 4             and it a really big bad thing about it

# %%
#create a word cloud of the most popular word in the tweets.
def wordcloud(tweets,col):
    stopwords = set(STOPWORDS)
    wordcloud = WordCloud(background_color="white",stopwords=stopwords,random_state = 2016).generate(" ".join([i for i in tweets[col]]))
    plt.figure( figsize=(15,8), facecolor='k')
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.title("Good Morning Datascience+")
wordcloud(tweets_df,'tweets')

# %%
# #Preprocessing del RT @blablabla:
# pd.options.mode.chained_assignment = None  # default='warn'
# tweets_df['tweets'] = '' 

# #add tweets first part
# for i in range(len(tweets_df['text'])):
#     try:
#         tweets_df['tweets'][i] = tweets_df['text'].str.split(' ')[i][0]
#     except AttributeError:    
#         tweets_df['tweets'][i] = 'other'

# #Preprocessing tweets. select tweets contains 'RT @'
# for i in range(len(tweets_df['text'])):
#     if tweets_df['tweets'].str.contains('@')[i]  == False:
#         tweets_df['tweets'][i] = 'other'
        
# # remove URLs, RTs, and twitter handles
# for i in range(len(tweets_df['text'])):
#     tweets_df['text'][i] = " ".join([word for word in tweets_df['text'][i].split()
#                                 if 'http' not in word and '@' not in word and '<' not in word])


# tweets_df['text'][1]

# %%
# tweets_df['tweets'] = '' 
# tweets_df.head()

# for i in range(len(tweets_df['text'])):
#     try:
#         tweets_df.loc[:,'tweets'] = tweets_df['text'].str.split(' ')[i][0]
#     except:
#         tweets_df.loc[:,'tweets'] = 'other'
# #     return tweets_df
        
        
# #print(tweets_df['text'].str.split()[0][0])
# tweets_df.head()

# %%
# # dc = tweets_df.loc[:,'tweets'].str.contains('@')[0]
# # dc
# pd.options.mode.chained_assignment = None  # default='warn'
# for i in range(len(tweets_df['text'].head(10))):
#     tweets_df['tweets'][i] = tweets_df['text'].str.split(' ')[i][0]

# tweets_df

# %%
# for i in range(len(tweets_df['text'])):
#     if tweets_df.loc[:,'tweets'].str.contains('@')  == False:
#         tweets_df.loc[:,'tweets'] = 'other'
